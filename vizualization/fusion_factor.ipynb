# %% [markdown]
# # VisDrone, YOLOv5s, 100 Epochs, #Params: 9.126M, #FLOPs: 23.954G

# %%
import matplotlib.pyplot as plt

# 데이터
high_map_50 = 35.964
low_map_50 = 35.964
# fusion_factors = [0.0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0]
# high_map_50_results = [30.816, 35.706, 35.977, 36.276, 35.964, 35.877, 36.054, 35.955, 36.099]
# low_map_50_results = [27.628, 35.619, 36.004, 35.827, 35.964, 36.114, 36.067, 36.132, 36.174]
fusion_factors = [0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0]
high_map_50_results = [35.706, 35.977, 36.276, 35.964, 35.877, 36.054, 35.955, 36.099]
low_map_50_results = [35.619, 36.004, 35.827, 35.964, 36.114, 36.067, 36.132, 36.174]

# 개선된 성능 (%)
high_map_50_improve_percent = [(m - high_map_50) / high_map_50 * 100 for m in high_map_50_results]
low_map_50_improve_percent = [(t - low_map_50) / low_map_50 * 100 for t in low_map_50_results]

# 시각화
plt.figure(figsize=(8, 5))

plt.plot(fusion_factors, high_map_50_improve_percent, 
         marker='o', linestyle='-', linewidth=2, markersize=6,
         label=r'$\alpha$ to High-level Features', color='royalblue')

plt.plot(fusion_factors, low_map_50_improve_percent, 
         marker='s', linestyle='-', linewidth=2, markersize=6,
         label=r'$\alpha$ to Low-level Features', color='seagreen')

# 기준선 (0% 향상 지점)
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.axvline(1.0, color='gray', linestyle=':', linewidth=1.5, label=r'$\alpha=1$ (baseline)')

# 축 설정
plt.xticks(fusion_factors, [str(f) for f in fusion_factors], fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'Fusion Factor $(\alpha)$', fontsize=15)
plt.ylabel(r'$\frac{\mathrm{mAP50}(\alpha) - \mathrm{mAP50}(\alpha=1)}{\mathrm{mAP50}(\alpha=1)}(\%)$', fontsize=20)

# 제목과 범례
# plt.title('Effect of Fusion Factor', fontsize=15)
plt.legend(fontsize=10, loc='lower right')
plt.grid(True, linestyle='--', alpha=0.5)

# 저장 및 출력
plt.tight_layout()
plt.title('YOLOv5s-VisDrone-640-FF.png', fontsize=15)
plt.savefig("YOLOv5s-VisDrone-640-FF.png", dpi=1200, bbox_inches='tight')
plt.show()

# %% [markdown]
# # VOC, YOLOv8s, 100 Epochs, #Params: 11.143M, #FLOPs: 57.168G

# %%
import matplotlib.pyplot as plt


high_map_50 = 81.218
low_map_50 = 81.218
fusion_factors = [0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0]
high_map_50_results = [81.129, 81.257, 81.143, 81.218, 81.378, 81.281, 81.491, 81.288]
low_map_50_results = [80.887, 80.865, 81.419, 81.218, 81.265, 81.259, 81.527, 81.054]

# 개선된 성능 (%)
high_map_50_improve_percent = [(m - high_map_50) / high_map_50 * 100 for m in high_map_50_results]
low_map_50_improve_percent = [(t - low_map_50) / low_map_50 * 100 for t in low_map_50_results]

# 시각화
plt.figure(figsize=(8, 5))

plt.plot(fusion_factors, high_map_50_improve_percent, 
         marker='o', linestyle='-', linewidth=2, markersize=6,
         label=r'$\alpha$ to High-level Features', color='royalblue')

plt.plot(fusion_factors, low_map_50_improve_percent, 
         marker='s', linestyle='-', linewidth=2, markersize=6,
         label=r'$\alpha$ to Low-level Features', color='seagreen')

# 기준선 (0% 향상 지점)
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.axvline(1.0, color='gray', linestyle=':', linewidth=1.5, label=r'$\alpha=1$ (baseline)')

# 축 설정
plt.xticks(fusion_factors, [str(f) for f in fusion_factors], fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'Fusion Factor $(\alpha)$', fontsize=15)
plt.ylabel(r'$\frac{\mathrm{mAP50}(\alpha) - \mathrm{mAP50}(\alpha=1)}{\mathrm{mAP50}(\alpha=1)}(\%)$', fontsize=20)

# 제목과 범례
# plt.title('Effect of Fusion Factor', fontsize=15)
plt.legend(fontsize=10, loc='lower right')
plt.grid(True, linestyle='--', alpha=0.5)

# 저장 및 출력
plt.tight_layout()
plt.title('YOLOv8s-VOC-640-FF.png', fontsize=15)
plt.savefig("YOLOv8s-VOC-640-FF.png", dpi=1200, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt


high_map_50 = 42.395
low_map_50 = 42.395
fusion_factors = [0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0]
high_map_50_results = [42.505, 43.092, 42.172, 42.395, 42.399, 42.385, 42.532, 42.542]
low_map_50_results = [41.897, 42.15, 42.162, 42.395, 42.487, 42.485, 42.698, 42.403]

# 개선된 성능 (%)
high_map_50_improve_percent = [(m - high_map_50) / high_map_50 * 100 for m in high_map_50_results]
low_map_50_improve_percent = [(t - low_map_50) / low_map_50 * 100 for t in low_map_50_results]

# 시각화
plt.figure(figsize=(8, 5))

plt.plot(fusion_factors, high_map_50_improve_percent, 
         marker='o', linestyle='-', linewidth=2, markersize=6,
         label=r'$\alpha$ to High-level Features', color='royalblue')

plt.plot(fusion_factors, low_map_50_improve_percent, 
         marker='s', linestyle='-', linewidth=2, markersize=6,
         label=r'$\alpha$ to Low-level Features', color='seagreen')

# 기준선 (0% 향상 지점)
plt.axhline(0, color='gray', linestyle='--', linewidth=1)
plt.axvline(1.0, color='gray', linestyle=':', linewidth=1.5, label=r'$\alpha=1$ (baseline)')

# 축 설정
plt.xticks(fusion_factors, [str(f) for f in fusion_factors], fontsize=11)
plt.yticks(fontsize=11)
plt.xlabel(r'Fusion Factor $(\alpha)$', fontsize=15)
plt.ylabel(r'$\frac{\mathrm{mAP50}(\alpha) - \mathrm{mAP50}(\alpha=1)}{\mathrm{mAP50}(\alpha=1)}(\%)$', fontsize=20)

# 제목과 범례
plt.legend(fontsize=10, loc='lower right')
plt.grid(True, linestyle='--', alpha=0.5)

# 저장 및 출력
plt.tight_layout()
plt.title('YOLOv8s-VisDrone-800-FF.png', fontsize=15)
plt.savefig("YOLOv8s-VisDrone-800-FF.png", dpi=1200, bbox_inches='tight')
plt.show()
